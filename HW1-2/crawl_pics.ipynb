# %%
import requests
from bs4 import BeautifulSoup
from tqdm import trange, tqdm
from time import sleep
import json

def read_jsonl(filename):
    data = []
    with open(filename, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))
    return data

def dict_to_jsonl(dicts, filename):
    with open(filename, 'w', encoding='utf-8') as f:
        for d in dicts:
            json.dump(d, f, ensure_ascii=False)
            f.write('\n')
            
def check_valid_pic_url(url):
    return url and \
        any(url.lower().endswith(x) for x in ['.jpg', '.jpeg', '.png']) and \
        any(url.lower().startswith(x) for x in ['http://', 'https://'])
        
def get_soup(url) -> BeautifulSoup:
    response = requests.get(url, headers = {'cookie': 'over18=1;'})
    return BeautifulSoup(response.text, "html.parser")

# %%
def convert_push_to_int(push_text):
    if push_text.isdigit():
        return int(push_text)
    elif push_text == '爆':
        return 100
    elif push_text == 'XX':
        return -100
    elif push_text == '':
        return 0
    elif push_text[0] == 'X':
        return -10 * int(push_text[1])
    else:
        return 0

page_range = (3656, 3944)
base_url = 'https://www.ptt.cc'

popular = []
not_popular = []

for page_num in trange(page_range[0], page_range[1] + 1):
    url = f'https://www.ptt.cc/bbs/Beauty/index{page_num}.html'
    soup = get_soup(url)
    for article in soup.find_all('div', 'r-ent'):
        title = article.find('div', 'title').text.strip()
        date = article.find('div', 'date').text.strip()
        url = base_url + article.find('div', 'title').a['href']
        
        push_text = x.text if (x := article.find('div', 'nrec').span) else ''
        push = convert_push_to_int(push_text)

        # 12/31 -> 1231, 1/01 -> 0101
        date = date.replace('/', '')
        date = date if len(date) == 4 else '0' + date
        
        if page_num == page_range[0] and date == '1231':
            continue
        elif page_num == page_range[1] and date == '0101':
            break
        
        if title.startswith('[公告]') or \
            title.startswith('Fw:[公告]') or \
            title.startswith('(本文已被刪除)') or \
            title.startswith('(已被'):
            continue
        
        if push > 35:
            popular.append({
                'date': date,
                'title': title,
                'url': url,
                'push': push_text
            })
        else:
            not_popular.append({
                'date': date,
                'title': title,
                'url': url,
                'push': push_text
            })
# Out:
#   0%|          | 0/289 [00:00<?, ?it/s]
# 100%|██████████| 289/289 [02:03<00:00,  2.33it/s]

# %%
def get_all_pic_urls(articles):  
    img_urls = []
    for article in tqdm(articles):
        soup = get_soup(article['url'])
        urls = [x for a in soup.find_all('a') if (x := a.get('href'))]
        urls = [url for url in urls if check_valid_pic_url(url)]
        
        img_urls.extend(urls)
        sleep(0.1)
    
    return img_urls

# %%
result = {
    'popular': {
        'articles': popular,
        'image_urls': get_all_pic_urls(popular) 
    },
    'not_popular': {
        'articles': not_popular,
        'image_urls': get_all_pic_urls(not_popular) 
    },
}
# Out:
# 100%|██████████| 1036/1036 [09:41<00:00,  1.78it/s]
# 100%|██████████| 4648/4648 [39:21<00:00,  1.97it/s]

# %%
# delete duplicate urls
result['popular']['image_urls'] = list(set(result['popular']['image_urls']))
result['not_popular']['image_urls'] = list(set(result['not_popular']['image_urls']))

# %%
# dump to json  
with open(f'pic_urls.json', 'w', encoding='utf-8') as f:
    json.dump(result, f, ensure_ascii=False, indent=4)

# %%
# load from json
with open('pic_urls.json', 'r', encoding='utf-8') as f:
    result = json.load(f)

# %%
# parallel downloader
import os
import requests
from concurrent.futures import ThreadPoolExecutor
from typing import List
import shutil

# replace invalid characters("\\/:*?\"<>|") with _
def remove_invalid_char(name):
    return ''.join([c for c in name if c not in '\\/:*?\"<>|'])

error_count = 0 
# not_exist_image = open('not_exist.jpg', 'rb')
def download_images(urls: List[str], path: str):
    def download(url):
        global error_count
        try:
            filename = url.split('/')[-1]
            filename = remove_invalid_char(filename)
            response = requests.get(url, stream=True, headers = {'User-Agent': 'Mozilla/5.0'})
            
            file_url = os.path.join(path, filename)
            with open(file_url, 'wb') as out_file:
                shutil.copyfileobj(response.raw, out_file)
                
            del response
            
            # compare the downloaded image with the not_exist image
            with open('./not_exist.jpg', 'rb') as f:
                not_exist = f.read()
                with open(file_url, 'rb') as f:
                    downloaded = f.read()
                # delete if the downloaded image is the same as the not_exist image
                if not_exist == downloaded:
                    os.remove(file_url)
                    print(f'Not exist, url: {url}')
                    return
                    
            # check file size 
            if os.path.getsize(file_url) <= 4096:
                os.remove(file_url)
                print(f'File too small, url: {url}')
                return
        except Exception as e:
            print(f'Error: {e}, url: {url}')
            error_count += 1
            return
        
        # delay to prevent from being banned
        sleep(10)
        
    
    max_workers = os.cpu_count() or 1
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        executor.map(download, urls)
        
    # wait for all the download to finish
    executor.shutdown(wait=True)

# %%
if not os.path.exists('./popular_1'):
    os.makedirs('./popular_1')
if not os.path.exists('./not_popular_1'):
    os.makedirs('./not_popular_1')
    
download_images(result['popular']['image_urls'], './popular_1')
download_images(result['not_popular']['image_urls'], './not_popular_1')
# Out:
# Not exist, url: https://i.imgur.com/HyK2SD2.jpg
# Not exist, url: https://i.imgur.com/IVQUDQC.jpg
# Not exist, url: https://i.imgur.com/H9mIvDc.jpg
# Not exist, url: https://i.imgur.com/mhXbMw4.jpg
# File too small, url: https://d.img.vision/dddshay/010.jpg
# Not exist, url: https://i.imgur.com/8l6XHPa.jpg
# Not exist, url: https://i.imgur.com/BpcVHZR.jpg
# Not exist, url: https://i.imgur.com/l39RL16.jpg
# Not exist, url: https://i.imgur.com/UhNomUM.jpg
# Not exist, url: https://i.imgur.com/VyXJrH7.jpg
# Not exist, url: https://i.imgur.com/5Ojl5tU.jpg
# Not exist, url: https://i.imgur.com/t56shvY.jpg
# Not exist, url: https://i.imgur.com/1eP9qU6.jpg
# Not exist, url: http://i.imgur.com/TPVZWn5.jpg
# Not exist, url: https://i.imgur.com/JdCoCjB.jpg
# Not exist, url: https://i.imgur.com/z0bj6Y8.jpg
# Not exist, url: https://i.imgur.com/Op89Xwh.jpg
# Not exist, url: https://i.imgur.com/pdVw9ra.jpg
# Not exist, url: https://i.imgur.com/6VN2bgd.jpg
# Not exist, url: https://i.imgur.com/lcAbgz2.jpg
# Not exist, url: https://i.imgur.com/qbpfsW5.jpeg
# Not exist, url: https://i.imgur.com/1gOnwpm.jpg
# Not exist, url: https://i.imgur.com/GANGyLV.jpg
# Not exist, url: https://i.imgur.com/Kq5xm4T.jpg
# Not exist, url: https://i.imgur.com/OsDQD6i.jpg
# Not exist, url: https://i.imgur.com/SBY9Pxd.jpg
# Not exist, url: https://i.imgur.com/HHtgTk4.jpg
# Not exist, url: https://i.imgur.com/OI6zxVd.jpg
# Not exist, url: https://i.imgur.com/I67l8Ih.jpg
# Not exist, url: https://i.imgur.com/4ESfRue.jpg
# Not exist, url: https://i.imgur.com/pKppsIb.jpg
# Not exist, url: https://i.imgur.com/WI8rEVR.jpg
# Not exist, url: https://i.imgur.com/q8KVpt5.jpg
# Not exist, url: https://i.imgur.com/wCVwZTr.jpeg
# Not exist, url: https://i.imgur.com/tOrtlyH.jpg
# Not exist, url: https://i.imgur.com/KQ9oTO1.jpg
# Not exist, url: https://i.imgur.com/FVIeraP.jpg
# Not exist, url: https://i.imgur.com/NIwrEVQ.jpg
# Not exist, url: https://i.imgur.com/uhz3fKu.jpg
# Not exist, url: https://i.imgur.com/2Ij1Uv0.jpg
# Not exist, url: https://i.imgur.com/idFSyck.jpg
# Not exist, url: https://i.imgur.com/qWYh3Jp.jpg
# Not exist, url: https://i.imgur.com/PsL1h3E.jpg
# Not exist, url: https://i.imgur.com/azGvk5x.jpg
# Not exist, url: https://i.imgur.com/xlEQpaX.jpg
# Not exist, url: https://i.imgur.com/o5uM54v.png
# Not exist, url: https://i.imgur.com/unXpCSI.jpg
# Not exist, url: https://i.imgur.com/kisjBE2.jpg
# Not exist, url: https://i.imgur.com/Qvtboma.jpg
# File too small, url: https://d.img.vision/beauty/kusano_015.jpg
# Not exist, url: https://i.imgur.com/mZX9g3a.jpg
# Not exist, url: https://i.imgur.com/Sj7bDbr.jpg
# Not exist, url: https://i.imgur.com/kGPYsIO.jpg
# File too small, url: https://d.img.vision/beauty/7.jpg
# Not exist, url: https://i.imgur.com/uXh36LW.png
# Not exist, url: https://i.imgur.com/LR2UOd9.png
# Not exist, url: https://i.imgur.com/uSVZCrt.jpeg
# File too small, url: https://d.img.vision/dddshay/18.jpg
# File too small, url: https://d.img.vision/beauty/3.jpg
# Not exist, url: https://i.imgur.com/ODbsVAT.jpg
# Not exist, url: https://i.imgur.com/qZjBFAw.png
# File too small, url: https://d.img.vision/dddshay/pb2023007.jpg
# Not exist, url: https://i.imgur.com/FdvuaGp.jpg
# Not exist, url: https://i.imgur.com/zb5QyOP.jpeg
# Not exist, url: https://i.imgur.com/LhlGvVh.png
# Not exist, url: https://i.imgur.com/lbg1MD6.jpg
# Not exist, url: https://i.imgur.com/KMgKtU0.png
# Not exist, url: https://i.imgur.com/tjVpSUE.jpeg
# Not exist, url: https://i.imgur.com/POWETVA.jpg
# Not exist, url: https://i.imgur.com/CTqszc6.png
# File too small, url: https://d.img.vision/dddshay/ww001_(2).jpg
# Not exist, url: https://i.imgur.com/Xzp0nEw.jpg
# Not exist, url: https://i.imgur.com/mWtmCID.jpg
# Not exist, url: https://i.imgur.com/QMUQDqz.jpg
# Not exist, url: https://i.imgur.com/BmVkLnT.jpg
# Not exist, url: https://i.imgur.com/2tACRik.jpg
# Not exist, url: https://i.imgur.com/d52IOtA.jpeg
# Not exist, url: https://i.imgur.com/Ycl9lCX.jpg
# File too small, url: https://d.img.vision/dddshay/pb2023005.jpg
# Not exist, url: https://i.imgur.com/2lueRZ6.jpg
# Not exist, url: https://i.imgur.com/KGK26Zk.jpg
# Not exist, url: https://i.imgur.com/qMWBXWF.jpg
# Not exist, url: https://i.imgur.com/DiqIwnD.jpg
# Not exist, url: https://i.imgur.com/RGfMXVw.jpg
# Not exist, url: https://i.imgur.com/CnllniB.jpeg
# Not exist, url: https://i.imgur.com/vb28jb0.jpg
# Not exist, url: https://i.imgur.com/VSNDQWZ.jpg
# Not exist, url: https://i.imgur.com/QusrQ0P.png
# Not exist, url: https://i.imgur.com/x3wBcLs.jpg
# Not exist, url: https://i.imgur.com/XXr8DfT.jpg
# Not exist, url: https://i.imgur.com/z1YheLd.jpg
# Not exist, url: https://i.imgur.com/faETyMu.jpg
# Not exist, url: https://i.imgur.com/QzNbEy0.jpg
# Not exist, url: https://i.imgur.com/kM0Nuwy.jpeg
# Not exist, url: https://i.imgur.com/SHzwWyG.jpeg
# Not exist, url: https://i.imgur.com/0Gbg0pW.jpg
# Not exist, url: https://i.imgur.com/xnebyYj.jpg
# Not exist, url: https://i.imgur.com/SH9sHF4.jpg
# Not exist, url: https://i.imgur.com/zGcqYVz.png
# Not exist, url: https://i.imgur.com/IptHN5S.png
# Not exist, url: https://i.imgur.com/Ua2xFDm.png
# Not exist, url: https://i.imgur.com/8SnWvKo.jpeg
# Not exist, url: https://i.imgur.com/LcpZAW0.jpg
# Not exist, url: https://i.imgur.com/1KMJ2IX.jpg
# File too small, url: https://d.img.vision/beauty/kusano_010.jpg
# Not exist, url: https://imgur.com/4ACdFUh.jpg
# File too small, url: https://d.img.vision/beauty/kusano_014.jpg
# Not exist, url: https://i.imgur.com/Dk0lcT0.jpg
# Not exist, url: https://i.imgur.com/la0qjJr.jpeg
# Not exist, url: https://i.imgur.com/33Y8dE0.jpg
# Not exist, url: https://i.imgur.com/HPJlyN7.jpg
# Not exist, url: https://i.imgur.com/I5mKp25.jpg
# Not exist, url: https://i.imgur.com/19lVH09.jpg
# Not exist, url: https://i.imgur.com/u6o47KM.jpg
# Not exist, url: https://imgur.com/g6C8zHd.jpg
# Not exist, url: https://i.imgur.com/BvGFJto.jpg
# Not exist, url: https://i.imgur.com/5cFsv2f.jpg
# Not exist, url: https://i.imgur.com/eQKaQvE.jpg
# Not exist, url: https://i.imgur.com/exdRMzf.jpg
# Not exist, url: https://i.imgur.com/J8IZsXY.jpg
# Not exist, url: https://i.imgur.com/HnFdFL5.jpg
# File too small, url: https://d.img.vision/beauty/19.jpg
# Not exist, url: https://i.imgur.com/K6997C9.jpg
# Not exist, url: https://i.imgur.com/yu0iKdV.jpeg
# Not exist, url: https://i.imgur.com/g2XPaHC.jpg
# Not exist, url: https://i.imgur.com/4Q47Gls.jpg
# Not exist, url: https://i.imgur.com/uJ5WtVe.jpg
# Not exist, url: https://i.imgur.com/CFkraGR.jpg
# Not exist, url: https://i.imgur.com/uHPZjjZ.jpg
# Not exist, url: https://i.imgur.com/xjYiWNz.jpeg
# Not exist, url: https://i.imgur.com/vEzGBm8.jpg
# Not exist, url: https://i.imgur.com/4EFFBTW.jpg
# Not exist, url: https://i.imgur.com/43kPZL8.jpg
# Not exist, url: https://i.imgur.com/68VGJtV.jpg
# Not exist, url: https://i.imgur.com/gN6my94.jpg
# Not exist, url: https://i.imgur.com/ySVZ5w5.jpg
# Not exist, url: https://i.imgur.com/Tn81iRG.jpg
# Not exist, url: https://i.imgur.com/6dWrsxT.jpeg
# Not exist, url: https://i.imgur.com/DAmSTF5.jpg
# Not exist, url: https://i.imgur.com/2agKQwJ.jpg
# Not exist, url: https://i.imgur.com/5Zo4nS7.jpg
# File too small, url: https://d.img.vision/dddshay/pb2023009.jpg
# Not exist, url: https://i.imgur.com/RECF6qC.jpg
# Not exist, url: https://i.imgur.com/00tE2ac.png
# Not exist, url: https://i.imgur.com/6aqnO6B.jpg
# Not exist, url: https://i.imgur.com/EX2miuN.jpg
# Not exist, url: https://i.imgur.com/5mvhzsH.jpg
# File too small, url: https://d.img.vision/dddshay/fb194s7_en_1080.mp4_20231204_121340.430.jpg
# Not exist, url: https://i.imgur.com/1Tus3qn.jpg
# Not exist, url: https://i.imgur.com/Qs8jnyo.jpeg
# Not exist, url: https://i.imgur.com/DgiUlNl.jpg
# File too small, url: https://d.img.vision/beauty/kusano_003.jpg
# Not exist, url: https://i.imgur.com/QeYMBnL.jpg
# File too small, url: https://d.img.vision/dddshay/TWISTYS_Stacked_by_the_Pool_078.jpg
# Not exist, url: https://i.imgur.com/Cr1JWod.jpg
# Not exist, url: https://i.imgur.com/Jmjsnig.jpg
# Not exist, url: https://i.imgur.com/3RGucqE.jpg
# File too small, url: https://d.img.vision/beauty/14.jpg
# File too small, url: https://d.img.vision/beauty/kusano_012.jpg
# Not exist, url: https://i.imgur.com/5W6rif4.jpg
# Not exist, url: https://i.imgur.com/MVLk9IS.jpg
# Not exist, url: https://i.imgur.com/OfZdh7H.jpg
# Not exist, url: https://i.imgur.com/3GJgKPj.png
# Not exist, url: https://i.imgur.com/XBr8Nm6.jpg
# Not exist, url: https://i.imgur.com/S1ANDAB.jpg
# Not exist, url: https://i.imgur.com/UKH95xO.jpg
# Not exist, url: https://i.imgur.com/9TcE9e7.jpg
# Not exist, url: https://i.imgur.com/EvHMOKc.jpeg
# File too small, url: https://d.img.vision/beauty/kusano_0006.jpg
# Not exist, url: https://i.imgur.com/thTqHAu.jpg
# Not exist, url: https://i.imgur.com/hAk0WCA.jpg
# Not exist, url: http://i.imgur.com/WoTvZNd.jpg
# Not exist, url: https://i.imgur.com/6f4eEfd.jpg
# Not exist, url: https://i.imgur.com/G1tSGMO.jpg
# Not exist, url: https://i.imgur.com/9bG8NAH.jpg
# Not exist, url: https://i.imgur.com/zoF1A6R.jpg
# File too small, url: https://d.img.vision/beauty/kusano_002.jpg
# Not exist, url: https://i.imgur.com/gzVRmtH.jpg
# File too small, url: https://d.img.vision/dddshay/ww001_(1).jpg
# Not exist, url: https://i.imgur.com/7l3V7oK.jpg
# Not exist, url: https://i.imgur.com/zIKa2PV.jpg
# Not exist, url: https://i.imgur.com/tWX4iol.jpg
# Not exist, url: https://i.imgur.com/cp0H4eH.jpg
# File too small, url: https://d.img.vision/beauty/kusano_004.jpg
# Not exist, url: https://i.imgur.com/TNIu3LN.jpg
# Not exist, url: https://i.imgur.com/hfLrpQn.jpg
# Not exist, url: https://i.imgur.com/5a8bkFs.jpeg
# Not exist, url: https://i.imgur.com/CVzRez5.jpg
# Not exist, url: https://i.imgur.com/cj1R12f.jpg
# Not exist, url: https://i.imgur.com/Jg5mJGz.jpg
# Not exist, url: https://i.imgur.com/COM2rxj.jpg
# Not exist, url: https://i.imgur.com/ttCyn1W.jpg
# Not exist, url: https://i.imgur.com/i3NuNlp.jpg
# Not exist, url: https://i.imgur.com/FkzwrfV.jpg
# Not exist, url: https://i.imgur.com/AUowaUf.jpg
# File too small, url: https://d.img.vision/beauty/10.jpg
# Not exist, url: https://i.imgur.com/Uu0ni8h.jpg
# Not exist, url: https://i.imgur.com/Uz9nVAu.jpg
# Not exist, url: https://i.imgur.com/Wpp2fTR.jpeg
# Not exist, url: https://i.imgur.com/FgfOtVB.jpg
# Not exist, url: https://i.imgur.com/nf1FtDS.jpg
# Not exist, url: https://i.imgur.com/a81r9JL.jpg
# Not exist, url: https://i.imgur.com/tTRbdQ6.jpg
# Not exist, url: https://i.imgur.com/VnuuXxw.jpg
# Not exist, url: https://imgur.com/s4roCcA.jpg
# Not exist, url: https://i.imgur.com/eFq2KQI.jpg
# Not exist, url: https://i.imgur.com/QuMSpi6.jpg
# Not exist, url: https://i.imgur.com/4tnT7Hk.jpg
# Not exist, url: https://i.imgur.com/XWO2qou.jpg
# File too small, url: https://d.img.vision/dddshay/pb2023006.jpg
# Not exist, url: https://i.imgur.com/E7pmra8.jpg
# File too small, url: https://d.img.vision/beauty/11_2.jpg
# Not exist, url: https://i.imgur.com/WynzIVU.jpg
# Not exist, url: https://i.imgur.com/FUKNUrv.jpg
# Not exist, url: https://i.imgur.com/iyYhluk.jpg
# Not exist, url: https://i.imgur.com/D6Ouypz.jpg
# Not exist, url: https://i.imgur.com/GhuRq6u.jpeg
# Not exist, url: https://i.imgur.com/5ifhYEi.jpg
# Not exist, url: https://i.imgur.com/Zg5KEp9.jpg
# Not exist, url: https://i.imgur.com/lot3wT3.jpg
# Not exist, url: https://i.imgur.com/MohWuBb.jpg
# Not exist, url: https://i.imgur.com/M6VIDI6.jpg
# Not exist, url: https://i.imgur.com/B85HGWX.jpg
# Not exist, url: https://i.imgur.com/Vhs4Mxc.jpeg
# Not exist, url: https://i.imgur.com/mjjVBlO.jpeg
# File too small, url: https://d.img.vision/dddshay/ww001_(4).jpg
# Not exist, url: https://i.imgur.com/TUm8z64.jpg
# Not exist, url: https://i.imgur.com/xOyeRRA.jpg
# Not exist, url: https://i.imgur.com/1b1YX31.jpg
# Not exist, url: https://i.imgur.com/xEpPunn.jpg
# Not exist, url: https://i.imgur.com/eFywuge.jpg
# Not exist, url: https://i.imgur.com/4vtpjIk.jpg
# Not exist, url: https://i.imgur.com/9ifp0Cc.jpg
# Not exist, url: https://i.imgur.com/zu6mHei.jpg
# Not exist, url: https://i.imgur.com/VOAJ7wq.jpg
# Not exist, url: https://i.imgur.com/JgayWxP.jpg
# Not exist, url: https://i.imgur.com/AylHoAR.jpg
# File too small, url: https://d.img.vision/beauty/kusano_005.jpg
# Not exist, url: https://i.imgur.com/mUc3dDV.jpg
# Not exist, url: https://i.imgur.com/1mbg5ZV.jpg
# Not exist, url: https://i.imgur.com/2nPhVAw.jpg
# Not exist, url: https://i.imgur.com/c9zdmtK.png
# Not exist, url: https://i.imgur.com/EmX2j8U.jpg
# Not exist, url: https://i.imgur.com/aYP8aKK.jpg
# Not exist, url: https://i.imgur.com/JjXqYVk.jpg
# Not exist, url: https://i.imgur.com/TjcOldb.jpeg
# Not exist, url: https://i.imgur.com/IxK5eQs.jpg
# Not exist, url: https://i.imgur.com/lcJ0yrd.jpg
# Not exist, url: https://i.imgur.com/fDeFviV.jpg
# Not exist, url: https://i.imgur.com/m3f2Xiu.jpg
# Not exist, url: https://i.imgur.com/DjRIyxH.jpg
# Not exist, url: https://i.imgur.com/CDdIJir.jpeg
# Not exist, url: https://i.imgur.com/NtGJQ0u.jpg
# Not exist, url: https://i.imgur.com/iJrANBc.jpg
# Not exist, url: https://i.imgur.com/64gQWD8.jpg
# Not exist, url: https://i.imgur.com/yYXv7fF.jpg
# Not exist, url: https://i.imgur.com/4y9esXD.jpg
# Not exist, url: https://i.imgur.com/ozS7NSk.jpg
# Not exist, url: https://i.imgur.com/8cEHWGZ.jpg
# Not exist, url: https://i.imgur.com/89WUP6X.jpg
# Not exist, url: https://i.imgur.com/fRzUyzc.jpg
# Not exist, url: https://i.imgur.com/xrxHnf7.jpg
# Not exist, url: https://i.imgur.com/yHvGLRT.jpg
# Not exist, url: https://i.imgur.com/7zsaHVM.jpg
# Not exist, url: https://i.imgur.com/upZn1nq.jpg
# Not exist, url: https://i.imgur.com/c7mWPW1.jpg
# Not exist, url: https://i.imgur.com/FU1dKLY.jpg
# Not exist, url: http://i.imgur.com/P4M2LBp.jpg
# File too small, url: https://d.img.vision/dddshay/TWISTYS_Stacked_by_the_Pool_083.jpg
# Not exist, url: https://i.imgur.com/mfjTT0s.jpg
# Not exist, url: https://i.imgur.com/Df2FC8O.jpg
# Not exist, url: https://i.imgur.com/nE5cVKC.jpg
# Not exist, url: https://i.imgur.com/IyWxtPg.jpg
# Not exist, url: https://i.imgur.com/Ni21RW2.png
# Not exist, url: https://i.imgur.com/kk3npJ2.jpg
# Not exist, url: https://i.imgur.com/JKfxxWL.jpg
# Not exist, url: https://i.imgur.com/7BJpIX3.jpg
# Not exist, url: https://i.imgur.com/0l9RXd3.jpg
# Not exist, url: https://i.imgur.com/hgGE0uK.jpg
# Not exist, url: https://i.imgur.com/gzpcOSf.jpeg
# Not exist, url: https://i.imgur.com/hnrDfbM.jpg
# Not exist, url: https://i.imgur.com/VZGmtXP.jpg
# Not exist, url: https://i.imgur.com/vOvZDP2.jpg
# Not exist, url: https://i.imgur.com/WAgvTWr.jpg
# Not exist, url: https://i.imgur.com/d6wRClA.jpg
# Not exist, url: https://i.imgur.com/M2TjK6p.jpg
# Not exist, url: https://i.imgur.com/iW8ulua.jpg
# Not exist, url: https://i.imgur.com/j8VOFAO.jpg
# Not exist, url: https://i.imgur.com/aXvV4GL.jpg
# Not exist, url: https://i.imgur.com/tgk7nmX.jpg
# Not exist, url: https://i.imgur.com/kfbDjX9.jpg
# Not exist, url: https://i.imgur.com/bwCU25h.png
# Not exist, url: https://i.imgur.com/r76aTST.jpg
# Not exist, url: https://i.imgur.com/6E7jTVn.jpeg
# Not exist, url: https://i.imgur.com/FvUxK2j.jpg
# Not exist, url: https://i.imgur.com/Roapnub.jpg
# Not exist, url: https://i.imgur.com/Nhfcrcu.jpg
# Not exist, url: https://i.imgur.com/9o2lI0Z.jpg
# Not exist, url: https://i.imgur.com/LMYHfqs.jpg
# Not exist, url: https://i.imgur.com/uc9ktra.jpg
# Not exist, url: https://i.imgur.com/Yza5OV9.jpg
# Not exist, url: https://i.imgur.com/VMlNYWn.jpg
# Not exist, url: https://i.imgur.com/Q2vDju9.jpg
# Not exist, url: https://i.imgur.com/qV5QYCf.jpg
# Not exist, url: https://i.imgur.com/rPXUeRO.jpeg
# Not exist, url: https://i.imgur.com/t3isBz1.jpg
# Not exist, url: https://i.imgur.com/Q2YJ80V.jpg
# Not exist, url: https://i.imgur.com/0QuFBBp.jpg
# File too small, url: https://d.img.vision/beauty/20.jpg
# Not exist, url: https://i.imgur.com/IbyE66G.jpg
# Not exist, url: https://i.imgur.com/2mRQJMZ.jpg
# Not exist, url: https://i.imgur.com/4SNZ1J1.jpg
# Not exist, url: https://i.imgur.com/zh89tMT.jpg
# Not exist, url: http://i.imgur.com/IE5ITz4.jpg
# Not exist, url: https://i.imgur.com/IQrv07e.jpg
# File too small, url: https://d.img.vision/beauty/2.jpg
# Not exist, url: https://i.imgur.com/lWWamGO.jpg
# Not exist, url: https://i.imgur.com/Yad7rqj.jpg
# Not exist, url: https://i.imgur.com/i5q0nmH.jpg
# Not exist, url: https://i.imgur.com/Z8SJRY1.jpg
# Not exist, url: https://i.imgur.com/VEQHe03.jpg
# Not exist, url: https://i.imgur.com/ncq0tuX.jpg
# Not exist, url: https://i.imgur.com/7HY9Hln.jpg
# Not exist, url: https://i.imgur.com/FfgX2Ba.jpg
# Not exist, url: https://i.imgur.com/s21w4ut.png
# Not exist, url: https://i.imgur.com/CUO2gpt.jpeg
# Not exist, url: https://i.imgur.com/BTYd5cV.jpg
# Not exist, url: https://i.imgur.com/k1fcewe.jpg
# Not exist, url: https://i.imgur.com/wUUk58r.jpeg
# File too small, url: https://d.img.vision/beauty/kusano_008.jpg
# Not exist, url: https://i.imgur.com/tjrV2BZ.jpg
# Not exist, url: https://i.imgur.com/SV1O9UP.jpg
# File too small, url: https://img.theqoo.net/img/hjrDN.png
# Not exist, url: https://i.imgur.com/HsFNCjm.jpg
# Not exist, url: https://i.imgur.com/9F2TuRl.jpg
# Not exist, url: https://i.imgur.com/0eLYLeC.jpg
# Not exist, url: https://i.imgur.com/k689q7Q.jpg
# Not exist, url: https://i.imgur.com/wF4x1wI.jpg
# Not exist, url: https://i.imgur.com/PhuFn24.jpg
# Not exist, url: https://i.imgur.com/IbTPtAD.jpg
# Not exist, url: https://i.imgur.com/69DhJDs.jpg
# Not exist, url: https://i.imgur.com/2KRfc6D.jpg
# Not exist, url: https://i.imgur.com/3ieNGXt.jpeg
# Not exist, url: https://i.imgur.com/cHc3FPc.jpg
# Not exist, url: https://i.imgur.com/bpJsQw1.jpg
# Not exist, url: https://i.imgur.com/oknLokk.jpg
# Not exist, url: https://imgur.com/LKR7mAF.jpg
# Not exist, url: https://i.imgur.com/WvONvc5.jpg
# Not exist, url: https://i.imgur.com/HOr5fNq.jpg
# Not exist, url: https://i.imgur.com/QfHPSOq.jpg
# Not exist, url: https://i.imgur.com/YJWIXRK.jpg
# Not exist, url: https://i.imgur.com/0FIHx9u.jpg
# Not exist, url: https://i.imgur.com/WmI5ziV.jpg
# Not exist, url: https://i.imgur.com/jiql8FU.jpg
# Not exist, url: https://i.imgur.com/mC6K1S0.jpeg
# Not exist, url: https://i.imgur.com/TWNXnFH.jpg
# Not exist, url: https://i.imgur.com/wWPcMyv.jpg
# Not exist, url: https://i.imgur.com/0vnqsKG.jpg
# Not exist, url: https://i.imgur.com/UEuysh8.jpg
# Not exist, url: https://i.imgur.com/ghs2Yjl.jpg
# Not exist, url: https://i.imgur.com/n6jUpJh.jpg
# Not exist, url: https://i.imgur.com/ctx60Yx.jpg
# Not exist, url: https://i.imgur.com/OISqemi.jpg
# Not exist, url: https://i.imgur.com/AlYlRML.jpg
# Not exist, url: https://i.imgur.com/VoZGutn.jpg
# Not exist, url: https://i.imgur.com/LvYPOw7.jpg
# Not exist, url: https://i.imgur.com/qjhj4mw.jpg
# Not exist, url: https://i.imgur.com/wxBAZXc.jpg
# Not exist, url: https://i.imgur.com/6crhkWz.jpg
# Not exist, url: https://i.imgur.com/q6Pjhkk.jpeg
# Not exist, url: https://i.imgur.com/4T87bER.jpg
# Not exist, url: https://i.imgur.com/Hpx9q1a.jpg
# Not exist, url: https://i.imgur.com/rRCfbTv.jpg
# Not exist, url: https://i.imgur.com/QBXzhKv.jpg
# Not exist, url: https://i.imgur.com/PSXAIeK.jpg
# Not exist, url: https://i.imgur.com/MuIohue.jpg
# Not exist, url: https://i.imgur.com/VDBCa8a.jpg
# Not exist, url: https://i.imgur.com/I4e8BOk.jpg
# Not exist, url: https://i.imgur.com/mTkByv1.jpg
# Not exist, url: https://i.imgur.com/T9P9Szd.jpg
# Not exist, url: https://i.imgur.com/N15UyFP.jpg
# Not exist, url: https://i.imgur.com/XW4JgaZ.jpg
# Not exist, url: https://i.imgur.com/58QNGJq.jpg
# Not exist, url: https://i.imgur.com/Jjoop31.jpg
# Not exist, url: http://i.imgur.com/f2n1Xcs.jpg
# Not exist, url: https://i.imgur.com/m7Kkkim.jpg
# Not exist, url: https://i.imgur.com/2EnIkoN.jpg
# Not exist, url: https://i.imgur.com/i2xsr3N.jpeg
# Not exist, url: https://i.imgur.com/GiTAp0I.jpg
# Not exist, url: https://i.imgur.com/uvCnWt6.jpg
# Not exist, url: https://i.imgur.com/dVmOVkE.jpg
# Not exist, url: https://i.imgur.com/HTdicu7.png
# Not exist, url: https://i.imgur.com/4cfboDp.jpg
# Not exist, url: https://i.imgur.com/Z7JD5zp.jpg
# Not exist, url: https://i.imgur.com/ULuxakO.jpeg
# Not exist, url: https://i.imgur.com/wqKNZvV.jpg
# Not exist, url: https://i.imgur.com/tgHtkze.jpg
# File too small, url: https://d.img.vision/dddshay/pb20230011.jpg
# Not exist, url: https://i.imgur.com/9gFEN2I.jpg
# Not exist, url: https://i.imgur.com/QMSaW6Y.jpg
# Not exist, url: https://i.imgur.com/BWkEX3P.jpg
# Not exist, url: https://i.imgur.com/QsBjtDZ.jpg
# Not exist, url: https://i.imgur.com/jU3MrN2.jpg
# Not exist, url: https://i.imgur.com/sW1fJ4i.jpg
# Not exist, url: https://i.imgur.com/gOZOJXV.jpg
# Not exist, url: https://i.imgur.com/LdA6jfh.jpg
# Not exist, url: https://i.imgur.com/4AGpBoi.jpg
# Not exist, url: https://i.imgur.com/wjtBOnj.jpeg
# Not exist, url: https://i.imgur.com/5fYGJHr.jpg
# Not exist, url: https://i.imgur.com/b91ucrN.jpg
# Not exist, url: https://i.imgur.com/hXfWAwc.jpg
# Not exist, url: https://i.imgur.com/lU5JTIT.jpg
# Not exist, url: https://i.imgur.com/KVZhFjL.jpg
# Not exist, url: https://i.imgur.com/4oQ50ZW.jpg
# Not exist, url: https://i.imgur.com/8P4Uq1I.jpg
# Not exist, url: https://i.imgur.com/eDp3Sm5.jpg
# Not exist, url: https://i.imgur.com/aMmrAol.jpg
# Not exist, url: https://i.imgur.com/R8ZHHOO.jpg
# Not exist, url: https://i.imgur.com/vuLFaG4.jpg
# Not exist, url: https://i.imgur.com/usDLCcu.jpg
# Not exist, url: https://i.imgur.com/ZXRpqcR.jpg
# Not exist, url: https://i.imgur.com/E1YMLIC.jpg
# Not exist, url: https://i.imgur.com/gEkz38X.jpg
# Not exist, url: https://i.imgur.com/AJtrnHa.jpeg
# Not exist, url: https://i.imgur.com/kTY4cl6.jpg
# File too small, url: https://img.theqoo.net/img/Hyhcz.jpg
# Not exist, url: https://i.imgur.com/lKHXBZj.jpg
# Not exist, url: https://i.imgur.com/mf6jhEt.jpg
# Not exist, url: https://i.imgur.com/dj5zGVA.jpg
# Not exist, url: https://i.imgur.com/nGVQwhX.jpg
# Not exist, url: https://i.imgur.com/qJZYG8N.jpg
# Not exist, url: https://i.imgur.com/0cefdHL.jpg
# Not exist, url: https://i.imgur.com/8OGhaNG.jpg
# Not exist, url: https://i.imgur.com/OTWFiVH.jpg
# Not exist, url: https://i.imgur.com/8kvIttE.jpg
# Not exist, url: https://i.imgur.com/FLxqZot.jpg
# Not exist, url: https://i.imgur.com/iQ5MC1k.jpg
# Not exist, url: https://i.imgur.com/GnKk7ab.jpg
# Not exist, url: https://i.imgur.com/XedVsIS.jpeg
# Not exist, url: https://i.imgur.com/tCReQlX.jpg
# Not exist, url: https://i.imgur.com/gJmQmYz.jpg
# Not exist, url: https://i.imgur.com/r0YaJNX.jpg
# Not exist, url: https://i.imgur.com/CahJtZb.jpg
# Not exist, url: https://i.imgur.com/W3NCXEO.jpg
# Not exist, url: https://i.imgur.com/Wr9NlwV.jpg
# Not exist, url: https://i.imgur.com/MkUVOcE.jpg
# Not exist, url: https://i.imgur.com/2Db7jzN.jpeg
# File too small, url: https://d.img.vision/dddshay/pb2023003.jpg
# Not exist, url: https://i.imgur.com/4Faoy9j.jpg
# Not exist, url: https://i.imgur.com/YOO1vKw.png
# File too small, url: https://d.img.vision/dddshay/007.jpg
# Not exist, url: https://i.imgur.com/RAQ8XXr.jpg
# Not exist, url: https://i.imgur.com/XFB1Kvw.jpg
# Not exist, url: https://i.imgur.com/T1taUJy.jpg
# Not exist, url: https://i.imgur.com/a1IwU9s.jpg
# Not exist, url: https://i.imgur.com/u1moLfI.jpg
# Not exist, url: https://i.imgur.com/t3mNtJE.jpg
# Not exist, url: https://i.imgur.com/TAisVSA.jpg
# Not exist, url: https://i.imgur.com/cTMhZWR.jpg
# Not exist, url: https://i.imgur.com/G4C6jpV.jpg
# Not exist, url: https://i.imgur.com/UpozjTj.jpg
# Not exist, url: https://i.imgur.com/TXl8d0c.jpeg
# Not exist, url: https://i.imgur.com/cQqCek1.jpg
# Not exist, url: https://i.imgur.com/cC5qYhh.jpg
# Not exist, url: https://i.imgur.com/4MfWoFF.jpg
# Not exist, url: https://i.imgur.com/yDBCgte.jpg
# Not exist, url: https://i.imgur.com/ezRFLkH.jpeg
# Not exist, url: https://i.imgur.com/77MK6MR.jpg
# Not exist, url: https://i.imgur.com/Pgcj6cf.jpg
# Not exist, url: https://i.imgur.com/OXtdSjR.jpg
# Not exist, url: https://i.imgur.com/PNbHxCp.jpg
# Not exist, url: https://i.imgur.com/Mxn68yJ.jpg
# Not exist, url: https://i.imgur.com/ncSWCh6.jpg
# Not exist, url: https://i.imgur.com/2Om3ve4.jpg
# Not exist, url: https://i.imgur.com/3yKfKtU.jpeg
# Not exist, url: https://i.imgur.com/OkE1wOc.jpg
# Not exist, url: https://i.imgur.com/bQRRfeK.jpg
# Not exist, url: https://i.imgur.com/Z7JDAcD.jpg
# Not exist, url: https://i.imgur.com/hqPo6Jh.jpg
# Not exist, url: https://i.imgur.com/ebXwu0X.jpg
# Not exist, url: https://i.imgur.com/mhPZv5c.jpg
# Not exist, url: https://i.imgur.com/yf3UHv2.jpg
# Not exist, url: https://i.imgur.com/XIBCEiw.jpg
# Not exist, url: https://i.imgur.com/vqAEAQN.jpg
# Not exist, url: https://i.imgur.com/7gjprcJ.jpg
# Not exist, url: https://i.imgur.com/vLrsh6C.jpg
# Not exist, url: https://i.imgur.com/G5g4jOm.jpg
# Not exist, url: https://i.imgur.com/iJFy6wJ.jpg
# Not exist, url: https://i.imgur.com/HOO9psK.jpeg
# Not exist, url: https://i.imgur.com/82wfp3T.jpg
# Not exist, url: https://i.imgur.com/sjPlxz6.png
# File too small, url: https://d.img.vision/beauty/kusano_013.jpg
# Not exist, url: https://imgur.com/9jd5Jm1.jpg
# Not exist, url: https://i.imgur.com/y2E6rX1.jpg
# File too small, url: https://d.img.vision/beauty/11.jpg
# Not exist, url: https://i.imgur.com/1rIfu6G.jpg
# Not exist, url: https://i.imgur.com/5M0yGFY.jpeg
# Not exist, url: https://i.imgur.com/7nNUvfv.png
# File too small, url: https://d.img.vision/beauty/kusano_001.jpg
# Not exist, url: https://i.imgur.com/Zfe2paA.jpg
# Not exist, url: https://i.imgur.com/mRx75Rk.jpg
# Not exist, url: https://i.imgur.com/cJvXerx.jpg
# Not exist, url: https://i.imgur.com/ZMTreHk.jpg
# Not exist, url: https://i.imgur.com/Q2jwmbH.jpg
# Not exist, url: https://i.imgur.com/ssyiAiL.jpg
# Not exist, url: https://i.imgur.com/OXMhzV5.jpg
# Not exist, url: https://i.imgur.com/TA6RBU6.jpg
# Not exist, url: https://i.imgur.com/J65avOf.jpg
# Not exist, url: https://i.imgur.com/j8y8AKN.jpg
# Not exist, url: https://i.imgur.com/HkgpilJ.jpeg
# Not exist, url: https://i.imgur.com/zLPXrAi.jpg
# Not exist, url: https://i.imgur.com/qB2lxh2.jpg
# File too small, url: https://d.img.vision/beauty/4.jpg
# Not exist, url: https://imgur.com/GvQr6cc.jpg
# Not exist, url: https://i.imgur.com/C7ZF6RQ.jpg
# Not exist, url: https://i.imgur.com/TOUsfqH.jpg
# Not exist, url: https://i.imgur.com/q6PT1Fs.jpg
# Not exist, url: https://i.imgur.com/PNHNxZg.jpg
# Not exist, url: https://i.imgur.com/V35K5v5.jpg
# File too small, url: https://d.img.vision/beauty/5.jpg
# Not exist, url: https://i.imgur.com/r4ksVat.jpg
# Not exist, url: https://i.imgur.com/bpVqKPV.jpg
# Not exist, url: https://i.imgur.com/9RInPAZ.jpg
# Not exist, url: https://i.imgur.com/X2ncqV1.jpeg
# Not exist, url: https://i.imgur.com/FEGwa93.jpg
# Not exist, url: https://i.imgur.com/jSNctfR.jpg
# Not exist, url: https://i.imgur.com/K62btJe.jpg
# Not exist, url: https://i.imgur.com/1NvVa5O.jpg
# Not exist, url: https://i.imgur.com/tBEeH7N.jpg
# Not exist, url: https://i.imgur.com/M3m1Ujo.jpg
# Not exist, url: https://i.imgur.com/MinkTh3.jpg
# Not exist, url: https://i.imgur.com/t2gHmFk.jpg
# File too small, url: https://d.img.vision/dddshay/fb194s7_en_1080.mp4_20231204_121556.683.jpg
# Not exist, url: https://i.imgur.com/PIte40Z.jpg
# Not exist, url: https://i.imgur.com/cE6p4kA.jpg
# Not exist, url: https://i.imgur.com/hoqbGnu.jpg
# Not exist, url: https://i.imgur.com/HWX9SJ2.jpg
# Not exist, url: https://i.imgur.com/H9KAN58.jpg
# Not exist, url: https://i.imgur.com/6pYTTQG.jpg
# Not exist, url: https://i.imgur.com/Cr1bwet.jpg
# Not exist, url: https://i.imgur.com/JN8uUXr.jpg
# Not exist, url: https://i.imgur.com/cNfG2EB.jpg
# Not exist, url: https://i.imgur.com/tNTZNbT.jpg
# Not exist, url: https://i.imgur.com/3SvGZca.jpg
# Not exist, url: https://i.imgur.com/pQ0a2CZ.jpg
# Not exist, url: https://i.imgur.com/B8slvnJ.jpg
# Not exist, url: https://i.imgur.com/s8RHG0a.png
# Not exist, url: https://i.imgur.com/LxOjouU.jpg
# Not exist, url: https://i.imgur.com/QrLl5aA.jpg
# Not exist, url: https://i.imgur.com/CZ5u4KU.jpg
# Not exist, url: https://i.imgur.com/B5VhfYw.jpg
# Not exist, url: https://i.imgur.com/Cvgndnr.jpg
# Not exist, url: https://i.imgur.com/cUn9zfs.jpg
# Not exist, url: https://i.imgur.com/PSKAdSO.jpg
# Not exist, url: https://i.imgur.com/OFlsdQr.jpg
# Not exist, url: https://i.imgur.com/NOAwMVs.jpg
# Not exist, url: https://i.imgur.com/C5vNX8a.jpg
# Not exist, url: https://i.imgur.com/9FIaie5.jpg
# Not exist, url: https://i.imgur.com/QoPGXZG.jpg
# Not exist, url: https://imgur.com/vatZil5.jpg
# Not exist, url: https://i.imgur.com/xUOUSEn.jpg
# Not exist, url: https://i.imgur.com/f6pvba1.jpg
# Not exist, url: https://i.imgur.com/LPFDg1k.jpg
# Not exist, url: https://i.imgur.com/iKKNZvA.jpg
# File too small, url: https://d.img.vision/beauty/11_1.jpg
# Not exist, url: https://i.imgur.com/qudMnLX.jpg
# Not exist, url: https://i.imgur.com/m86lUEO.jpg
# Not exist, url: https://i.imgur.com/DbrK6vW.jpg
# Not exist, url: https://i.imgur.com/iVwCSEy.jpg
# Not exist, url: https://i.imgur.com/hh9qZeg.jpg
# Not exist, url: https://i.imgur.com/1RA746F.jpg
# Not exist, url: https://i.imgur.com/W4oOHD8.jpeg
# Not exist, url: https://i.imgur.com/fZ555sM.jpg
# Not exist, url: https://i.imgur.com/4q7JeTZ.jpg
# Not exist, url: https://i.imgur.com/9vLzXeN.jpg
# Not exist, url: https://i.imgur.com/QNl6W21.jpg
# Not exist, url: http://i.imgur.com/aHTaKk2.jpg
# Not exist, url: https://i.imgur.com/lbn8gXx.jpg
# Not exist, url: https://i.imgur.com/lXZlNX6.jpg
# Not exist, url: https://i.imgur.com/w883Fkx.jpg
# Not exist, url: https://i.imgur.com/qq9PmvS.jpg
# Not exist, url: https://i.imgur.com/VLfF4hb.jpg
# Not exist, url: https://i.imgur.com/tZ6sMj6.jpg
# Not exist, url: https://i.imgur.com/2R9pYzl.jpg
# Not exist, url: https://i.imgur.com/lQRkdAt.jpg
# Not exist, url: https://i.imgur.com/sZUMB1V.jpeg
# Not exist, url: https://i.imgur.com/PjWKqeb.jpg
# Not exist, url: https://i.imgur.com/jWCENWi.jpg
# Not exist, url: https://i.imgur.com/tuhkPh1.jpg
# Not exist, url: https://i.imgur.com/whXUOQo.jpeg
# Not exist, url: https://i.imgur.com/bON23uo.jpg
# Not exist, url: https://i.imgur.com/Ox8ZstI.jpg
# Not exist, url: https://i.imgur.com/MRgWBEV.jpg
# Not exist, url: https://i.imgur.com/rtZ4Yio.jpg
# Not exist, url: https://i.imgur.com/mUKJSz8.jpg
# Not exist, url: https://i.imgur.com/90VsORx.jpg
# Not exist, url: https://i.imgur.com/QXXWoRR.jpg
# Not exist, url: https://i.imgur.com/DTaoWib.jpg
# Not exist, url: https://i.imgur.com/aSRjXnX.jpg
# Not exist, url: https://i.imgur.com/pPsZv0V.jpg
# Not exist, url: https://i.imgur.com/oFJrtDw.jpg
# Not exist, url: https://i.imgur.com/oExtJL2.jpg
# Not exist, url: https://i.imgur.com/cqdm9Ny.jpg
# Not exist, url: https://i.imgur.com/SO0sl1t.jpg
# Not exist, url: https://i.imgur.com/dP1oyqQ.jpg
# Not exist, url: https://i.imgur.com/ITWVO3R.jpeg
# Not exist, url: https://i.imgur.com/oQ3CB1e.jpg
# Not exist, url: https://i.imgur.com/1L7HXk2.jpg
# Not exist, url: https://i.imgur.com/b9mvVKT.jpg
# Not exist, url: https://i.imgur.com/TcGK7pz.jpg
# Not exist, url: https://i.imgur.com/VmBfR2A.jpg
# Not exist, url: https://i.imgur.com/s0owEDZ.jpeg
# Not exist, url: https://i.imgur.com/WvasOqX.jpg
# Not exist, url: https://i.imgur.com/1BHVmet.jpg
# Not exist, url: https://i.imgur.com/ye1TEZT.jpg
# Not exist, url: https://i.imgur.com/jrV4bRC.jpg
# Not exist, url: https://i.imgur.com/6mwiI6H.jpg
# Not exist, url: https://i.imgur.com/BOWbV3E.jpg
# Not exist, url: https://i.imgur.com/vnwxZbu.jpg
# Not exist, url: https://i.imgur.com/61sQcjP.jpg
# Not exist, url: https://i.imgur.com/FSspCT5.jpg
# Not exist, url: https://i.imgur.com/b9d1tYc.jpg
# Not exist, url: https://i.imgur.com/U82x8XE.jpg
# Not exist, url: https://i.imgur.com/xGTFMG6.jpg
# Not exist, url: https://i.imgur.com/zUwGWOn.png
# Not exist, url: https://i.imgur.com/psY3hHO.jpg
# Not exist, url: https://i.imgur.com/xD8QHj9.jpg
# Not exist, url: https://i.imgur.com/lLiaaCQ.jpeg
# Not exist, url: https://i.imgur.com/JNtfgrL.jpg
# Not exist, url: https://i.imgur.com/DFXM0lh.jpg
# File too small, url: https://d.img.vision/dddshay/fb194s7_en_1080.mp4_20231204_121242.943.jpg
# Not exist, url: https://i.imgur.com/m0n8gPD.jpg
# Not exist, url: https://i.imgur.com/t8WiuC9.jpeg
# Not exist, url: https://i.imgur.com/WqzRUF4.jpg
# Not exist, url: https://i.imgur.com/KRnrBPU.jpg
# Not exist, url: https://i.imgur.com/1XQSqah.jpg
# Not exist, url: https://i.imgur.com/u2tkdap.jpeg
# Not exist, url: https://i.imgur.com/Lpj80K9.jpg
# Not exist, url: https://i.imgur.com/SAXaIRj.jpg
# Not exist, url: https://i.imgur.com/HNDl7jI.jpg
# Not exist, url: https://i.imgur.com/qaewh0L.jpeg
# Not exist, url: https://i.imgur.com/XaKrUlM.jpg
# Not exist, url: https://i.imgur.com/mgwyI2z.jpg
# Not exist, url: https://i.imgur.com/oylQd37.jpg
# File too small, url: https://d.img.vision/beauty/11_3.jpg
# Not exist, url: https://i.imgur.com/0gAyDJP.png
# Not exist, url: https://i.imgur.com/cNDSeLB.jpg
# Not exist, url: https://i.imgur.com/QMSYkIc.jpg
# Not exist, url: https://i.imgur.com/1OsA3ua.jpeg
# Not exist, url: https://i.imgur.com/VgDK769.jpg
# Not exist, url: https://i.imgur.com/tdQphXl.jpg
# Not exist, url: https://i.imgur.com/XAX4PLm.jpg
# Not exist, url: https://i.imgur.com/AieIMvD.jpeg
# File too small, url: https://d.img.vision/dddshay/TWISTYS_Stacked_by_the_Pool_094.jpg
# Not exist, url: https://i.imgur.com/3xOD6ZX.jpeg
# Not exist, url: https://i.imgur.com/wFggImn.jpg
# Not exist, url: https://i.imgur.com/7jYmvCW.jpg
# Not exist, url: https://i.imgur.com/PHTRCni.jpg
# Not exist, url: https://i.imgur.com/jUg0ODE.jpg
# Not exist, url: https://i.imgur.com/P9TiSv5.jpg
# Not exist, url: https://i.imgur.com/7ynIHbK.jpg
# Not exist, url: https://i.imgur.com/QUXlAhh.jpg
# Not exist, url: https://i.imgur.com/vlAZdHl.jpg
# Not exist, url: https://i.imgur.com/mkHyRVJ.jpg
# Not exist, url: https://i.imgur.com/Kw2wl3Q.jpeg
# Not exist, url: https://i.imgur.com/vyULxPf.jpg
# Not exist, url: https://i.imgur.com/gI2MjTo.jpg
# Not exist, url: https://i.imgur.com/VP5L4oe.jpg
# Not exist, url: https://i.imgur.com/c4t63q9.jpeg
# Not exist, url: https://i.imgur.com/v95dAmi.jpg
# Not exist, url: https://i.imgur.com/zYKUFEv.jpg
# Not exist, url: https://i.imgur.com/uUZpnnH.jpg
# Not exist, url: https://i.imgur.com/kzC9f0L.jpg
# Not exist, url: https://i.imgur.com/V14i274.jpg
# Not exist, url: https://i.imgur.com/5kNOo8Q.jpeg
# Not exist, url: https://i.imgur.com/dbQ8ydV.jpg
# Not exist, url: https://i.imgur.com/Kb2nLlR.jpg
# Not exist, url: https://i.imgur.com/6cogkDP.jpg
# Not exist, url: https://i.imgur.com/aE6J1HG.jpeg
# Not exist, url: https://i.imgur.com/5JAdAIE.jpeg
# Not exist, url: https://i.imgur.com/Y2qGw3F.jpg
# Not exist, url: https://i.imgur.com/UOVkYSX.jpg
# Not exist, url: https://i.imgur.com/ct87djV.jpg
# Not exist, url: https://i.imgur.com/7c59Jod.jpg
# Not exist, url: https://i.imgur.com/Ah3keL4.jpg
# Not exist, url: https://i.imgur.com/Boq9Ycf.jpg
# Not exist, url: https://i.imgur.com/z1Jck2b.jpg
# Not exist, url: https://i.imgur.com/3HbeIv7.jpg
# File too small, url: https://d.img.vision/dddshay/fb194s7_en_1080.mp4_20231204_121204.532.jpg
# Not exist, url: https://i.imgur.com/kXBcjna.jpg
# Not exist, url: https://i.imgur.com/bfUQOpt.jpg
# Not exist, url: https://i.imgur.com/5qT71VJ.png
# Not exist, url: https://i.imgur.com/ObthaTb.jpg
# Not exist, url: https://i.imgur.com/jAzhCIP.jpg
# Not exist, url: https://i.imgur.com/LFUcLfL.jpeg
# Not exist, url: https://i.imgur.com/8od8gUB.jpg
# Not exist, url: https://i.imgur.com/XkSKXkM.jpg
# Not exist, url: https://i.imgur.com/hs88cIe.jpg
# Not exist, url: https://i.imgur.com/NN44KGF.jpg
# Not exist, url: https://i.imgur.com/UNrFBgN.jpg
# Not exist, url: https://i.imgur.com/wjl1Xnb.jpg
# Not exist, url: https://i.imgur.com/JZ6xjkH.jpg
# Not exist, url: https://i.imgur.com/tLJhiFn.jpg
# File too small, url: https://d.img.vision/dddshay/fb194s7_en_1080.mp4_20231204_121225.264.jpg
# Not exist, url: https://i.imgur.com/Vrz4nZ4.jpg
# Not exist, url: https://i.imgur.com/NrgVUgH.jpeg
# Not exist, url: https://i.imgur.com/erIpYL8.jpg
# Not exist, url: https://i.imgur.com/kEb4gbP.jpg
# File too small, url: https://d.img.vision/beauty/17.jpg
# Not exist, url: https://i.imgur.com/w1lXhC2.jpg
# Not exist, url: https://i.imgur.com/H4giEmH.jpg
# Not exist, url: https://i.imgur.com/qONyxN8.jpg
# Not exist, url: https://i.imgur.com/vHewCPG.jpg
# Not exist, url: https://i.imgur.com/vhjPkbV.jpeg
# File too small, url: https://d.img.vision/beauty/kusano_009.jpg
# Not exist, url: https://i.imgur.com/u8CIiFh.jpg
# Not exist, url: https://i.imgur.com/BnH1FQu.jpeg
# Not exist, url: https://i.imgur.com/jm5Kic0.jpg
# File too small, url: https://d.img.vision/beauty/18.jpg
# Not exist, url: https://i.imgur.com/5PSdVkp.jpg
# Not exist, url: https://i.imgur.com/xUuoQkv.jpeg
# Not exist, url: https://i.imgur.com/duM78gN.jpg
# Not exist, url: https://i.imgur.com/0xghM0b.jpg
# Not exist, url: https://i.imgur.com/De6NG3b.jpg
# Not exist, url: https://i.imgur.com/hBMV3bN.jpg
# Not exist, url: https://i.imgur.com/W65kHZu.jpg
# Not exist, url: https://i.imgur.com/HriZQCr.jpg
# Not exist, url: https://i.imgur.com/9rIfZ7P.jpg
# Not exist, url: https://i.imgur.com/3YVoISW.jpeg
# File too small, url: https://pbs.twimg.com/media/FqnXns4akAE6nve.jpg
# Not exist, url: https://i.imgur.com/RcOQXRl.jpg
# Not exist, url: https://i.imgur.com/bmLO9n7.jpg
# Not exist, url: https://i.imgur.com/4K33BaM.jpg
# Not exist, url: https://i.imgur.com/u0HNGUA.jpg
# Not exist, url: https://i.imgur.com/2lEyIXM.jpg
# Not exist, url: https://i.imgur.com/T27L7YT.jpg
# Not exist, url: https://i.imgur.com/d4IJ6Wq.jpg
# Not exist, url: https://i.imgur.com/2SaHGve.jpg
# Not exist, url: https://i.imgur.com/33bDOWy.jpg
# Not exist, url: https://i.imgur.com/LrBn4NA.jpg
# Not exist, url: https://i.imgur.com/nPRwxwN.jpg
# Not exist, url: https://i.imgur.com/YpJjJcK.jpg
# File too small, url: https://d.img.vision/beauty/12.jpg
# Not exist, url: https://i.imgur.com/NloZOb1.jpeg
# Not exist, url: https://i.imgur.com/knXbk5E.jpg
# File too small, url: https://img.theqoo.net/img/VhIjF.png
# Not exist, url: https://i.imgur.com/vTEMNYI.jpg
# Not exist, url: https://i.imgur.com/xw7wI9e.jpg
# Not exist, url: https://i.imgur.com/NixIWzv.jpg
# Not exist, url: https://i.imgur.com/LZ87Lwj.jpg
# Not exist, url: https://i.imgur.com/Yjjb0SI.jpg
# Not exist, url: https://i.imgur.com/DTNL04q.jpg
# Not exist, url: https://i.imgur.com/wKAilPQ.jpg
# Not exist, url: https://i.imgur.com/RLkELlU.jpg
# Not exist, url: https://i.imgur.com/dBvSwyX.jpg
# Not exist, url: https://i.imgur.com/Xjz7ddL.jpeg
# Not exist, url: https://i.imgur.com/9BVF78W.jpg
# Not exist, url: https://i.imgur.com/5NExaEk.jpg
# Not exist, url: https://i.imgur.com/Y3YcFdo.jpg
# Not exist, url: https://i.imgur.com/YcM0rPH.jpg
# Not exist, url: https://i.imgur.com/lYEleuA.jpg
# Not exist, url: https://i.imgur.com/hmH2pA8.jpg
# Not exist, url: https://i.imgur.com/sIFeFNb.png
# Not exist, url: https://i.imgur.com/YDKHwqc.jpg
# File too small, url: https://img.theqoo.net/img/CvEWn.png
# Not exist, url: https://i.imgur.com/fqEvU7r.jpg
# Not exist, url: https://i.imgur.com/8jxNDQ5.jpg
# Not exist, url: https://i.imgur.com/I1n2Rjy.jpg
# Not exist, url: https://i.imgur.com/vGOdhGT.jpeg
# Not exist, url: https://i.imgur.com/ZjjyHAI.jpg
# Not exist, url: https://i.imgur.com/ZeoJgkc.jpg
# Not exist, url: https://i.imgur.com/1Yvb2Yt.jpg
# Not exist, url: https://i.imgur.com/w9I4Z1W.jpg
# File too small, url: https://d.img.vision/beauty/21.jpg
# Not exist, url: https://i.imgur.com/nhQ3O7Q.jpg
# Not exist, url: https://i.imgur.com/cYAVlgy.jpg
# Not exist, url: https://i.imgur.com/SW9k3IW.jpg
# File too small, url: https://d.img.vision/dddshay/pb2023004.jpg
# File too small, url: https://d.img.vision/beauty/6.jpg
# Not exist, url: https://i.imgur.com/AKszOrt.jpg
# Not exist, url: https://i.imgur.com/UE5voGj.jpg
# Not exist, url: https://i.imgur.com/SDj2WJy.jpg
# Not exist, url: https://i.imgur.com/3QynqPS.jpg
# Not exist, url: https://i.imgur.com/Fg1fXhX.jpg
# Not exist, url: https://i.imgur.com/JwsXQ3D.jpg
# Not exist, url: https://i.imgur.com/3UWQ8y6.jpg
# Not exist, url: https://i.imgur.com/xwLbO4T.jpeg
# Not exist, url: https://i.imgur.com/tys4WRu.jpg
# Not exist, url: https://i.imgur.com/nmCSlNn.jpg
# Not exist, url: https://i.imgur.com/bKE0JTk.jpeg
# Not exist, url: https://i.imgur.com/S9YuQkT.jpg
# Not exist, url: https://i.imgur.com/nPvzYrJ.jpeg
# Not exist, url: https://i.imgur.com/Mtx8H3Q.png
# Not exist, url: https://i.imgur.com/dmmds7V.jpg
# Not exist, url: https://i.imgur.com/U9hZvPR.jpg
# Not exist, url: https://i.imgur.com/NV2SSjG.jpg
# Not exist, url: https://i.imgur.com/qYp866Y.jpg
# Not exist, url: https://i.imgur.com/o5GEBmc.jpg
# Not exist, url: https://i.imgur.com/E1zRGQO.jpg
# Not exist, url: https://i.imgur.com/sQ9lqBI.jpg
# File too small, url: https://d.img.vision/dddshay/pb2023008.jpg
# Not exist, url: https://i.imgur.com/hDvfdDN.jpg
# Not exist, url: https://i.imgur.com/NvLjzHO.jpg
# Not exist, url: https://i.imgur.com/zmRaHVy.jpg
# Not exist, url: https://i.imgur.com/mf7jTqM.jpg
# Not exist, url: https://i.imgur.com/XrFxSer.jpg
# Not exist, url: https://i.imgur.com/d69zCS6.jpg
# Not exist, url: https://i.imgur.com/ugx9QU0.jpg
# Not exist, url: https://i.imgur.com/Wsv2yJZ.jpg
# Not exist, url: https://i.imgur.com/lPvawzZ.jpg
# Not exist, url: https://i.imgur.com/JtPCyFX.jpg
# Not exist, url: https://i.imgur.com/AqfYqoK.jpg
# Not exist, url: https://i.imgur.com/Ho6Wd0E.jpg
# Not exist, url: https://i.imgur.com/Pjg01pd.jpg
# Not exist, url: https://i.imgur.com/s1yFc3G.jpeg
# Not exist, url: https://i.imgur.com/xq7eReI.jpg
# Not exist, url: https://i.imgur.com/1Eu2Fj8.jpg
# Not exist, url: https://i.imgur.com/cqq5VUK.jpg
# Not exist, url: https://i.imgur.com/LgKxSoN.jpg
# Not exist, url: https://i.imgur.com/mDaldvj.jpg
# Not exist, url: https://i.imgur.com/gtYtQzT.jpg
# Not exist, url: https://i.imgur.com/JozFp1G.jpg
# Not exist, url: https://i.imgur.com/4pPb8Bx.jpg
# Not exist, url: https://i.imgur.com/iqq31vK.jpg
# Not exist, url: https://i.imgur.com/CTCdBvl.jpg
# Not exist, url: https://i.imgur.com/qk7yB1a.jpg
# File too small, url: https://d.img.vision/beauty/1.jpg
# Not exist, url: https://i.imgur.com/OWD5cA0.png
# Not exist, url: https://i.imgur.com/DNWSBJw.jpg
# Not exist, url: https://i.imgur.com/ZdUWvOH.jpg
# Not exist, url: https://i.imgur.com/77bAU4S.jpg
# Not exist, url: https://i.imgur.com/tLDNKRC.jpg
# Not exist, url: https://i.imgur.com/l8TKgQF.jpg
# Not exist, url: https://i.imgur.com/pi9wuYp.jpg
# Not exist, url: http://i.imgur.com/tDn1qr3.jpg
# Not exist, url: https://i.imgur.com/CTb28t2.jpg
# Not exist, url: https://i.imgur.com/xMJkQX2.jpg
# Not exist, url: https://i.imgur.com/v9sRYHe.jpeg
# Not exist, url: https://i.imgur.com/ZJTxMa7.jpg
# Not exist, url: https://i.imgur.com/zGrIhmE.jpg
# Not exist, url: https://i.imgur.com/bkFDuDz.jpg
# Not exist, url: https://i.imgur.com/PYrKCQm.jpg
# Not exist, url: https://i.imgur.com/dUXje4y.jpg
# Not exist, url: https://i.imgur.com/WEPwqnD.jpg
# Not exist, url: https://i.imgur.com/yKkrzkk.jpeg
# Not exist, url: https://i.imgur.com/KXvxhP5.jpg
# Not exist, url: https://i.imgur.com/IdWjvsc.png
# Not exist, url: https://i.imgur.com/23HbTrO.jpg
# Not exist, url: https://i.imgur.com/u7G6lCj.jpg
# Not exist, url: https://i.imgur.com/NuYHKPM.jpeg
# Not exist, url: https://i.imgur.com/6NB6ise.jpg
# Not exist, url: http://i.imgur.com/PHdRRmH.jpg
# File too small, url: https://d.img.vision/beauty/8.jpg
# Not exist, url: https://i.imgur.com/ypDKlzn.jpg
# Not exist, url: https://i.imgur.com/L1USrZi.png
# Not exist, url: https://i.imgur.com/PuaWryT.jpg
# Not exist, url: https://i.imgur.com/Gjicn3P.jpg
# Not exist, url: https://i.imgur.com/HTf8U2o.jpg
# Not exist, url: https://i.imgur.com/1g0qm6t.jpg
# Not exist, url: https://i.imgur.com/Pf7CEYL.jpg
# Not exist, url: https://i.imgur.com/PU6aXCI.jpg
# Not exist, url: https://i.imgur.com/hFVNlQG.jpeg
# Not exist, url: https://i.imgur.com/XKQIJ0n.jpeg
# Not exist, url: https://i.imgur.com/rKrdYIQ.jpg
# Not exist, url: https://i.imgur.com/WFOD57B.jpg
# Not exist, url: https://i.imgur.com/oM2QOpz.jpg
# File too small, url: https://d.img.vision/dddshay/ww001_(3).jpg
# Not exist, url: https://i.imgur.com/4D8CW6a.jpg
# Not exist, url: https://i.imgur.com/bxa2tti.jpg
# Not exist, url: https://i.imgur.com/8h9tvsm.jpg
# Not exist, url: https://i.imgur.com/7TC63ni.jpg
# Not exist, url: https://i.imgur.com/zqK1ohI.png
# Not exist, url: https://i.imgur.com/EcIyj64.jpg
# Not exist, url: https://i.imgur.com/JCqoI8Q.jpeg
# Not exist, url: https://i.imgur.com/aAVSrsU.jpg
# File too small, url: https://d.img.vision/beauty/16.jpg
# Not exist, url: https://i.imgur.com/owkHFC8.jpeg
# Not exist, url: https://i.imgur.com/969hVGk.jpg
# Not exist, url: https://i.imgur.com/ZcthqSX.jpg
# Not exist, url: https://i.imgur.com/IcYoAUn.jpg
# Not exist, url: https://i.imgur.com/uXIcOFV.jpg
# Not exist, url: https://i.imgur.com/D22d2dr.jpg
# Not exist, url: https://i.imgur.com/LYeGcxQ.jpg
# Not exist, url: https://i.imgur.com/v5TV3y6.jpg
# Not exist, url: https://i.imgur.com/nxZ95kj.jpg
# Not exist, url: https://i.imgur.com/p2ygSVQ.jpg
# Not exist, url: https://i.imgur.com/26WqsEF.png
# Not exist, url: https://i.imgur.com/LQls49l.jpg
# Not exist, url: https://i.imgur.com/iM0qS2v.jpg
# Not exist, url: https://i.imgur.com/OeHmQQR.jpg
# File too small, url: https://d.img.vision/dddshay/009.jpg
# Not exist, url: https://i.imgur.com/7jMz4Ll.jpg
# Not exist, url: https://i.imgur.com/muU8B0z.jpg
# Not exist, url: https://i.imgur.com/cMJPN6W.jpg
# File too small, url: https://d.img.vision/dddshay/07.jpg
# Not exist, url: https://i.imgur.com/dRdGOb4.jpeg
# Not exist, url: https://i.imgur.com/CF1mYhZ.jpeg
# Not exist, url: https://i.imgur.com/1Zh2Lg3.jpg
# Not exist, url: https://i.imgur.com/iT9xBb2.jpg
# Not exist, url: https://i.imgur.com/epdm20f.jpg
# Not exist, url: https://i.imgur.com/jeSIeGY.jpg
# Not exist, url: https://i.imgur.com/tR6NV4N.jpg
# Not exist, url: https://i.imgur.com/bgcOa7O.jpg
# Not exist, url: https://i.imgur.com/NKdXMlu.jpg
# Not exist, url: https://i.imgur.com/0M6KlK2.jpg
# Not exist, url: https://i.imgur.com/ruP7ohp.jpg
# Not exist, url: http://i.imgur.com/bmPNM0j.jpg
# Not exist, url: https://i.imgur.com/TXOdNIS.jpg
# Not exist, url: https://i.imgur.com/iYsuuMd.jpg
# Not exist, url: https://i.imgur.com/WmeQxpM.jpg
# Not exist, url: https://i.imgur.com/jadxBqZ.jpg
# Not exist, url: https://i.imgur.com/Vjoaaqm.jpg
# Not exist, url: https://i.imgur.com/0vLeSBv.jpg
# Not exist, url: https://i.imgur.com/tevctC7.jpg
# Not exist, url: https://i.imgur.com/p6Lt1sf.jpg
# Not exist, url: https://i.imgur.com/NHlVHKB.jpg
# Not exist, url: http://i.imgur.com/ewWWIFh.jpg
# Not exist, url: http://i.imgur.com/7dHKias.jpg
# Not exist, url: https://i.imgur.com/jM4nS0K.jpg
# Not exist, url: https://i.imgur.com/n0mXg23.jpg
# Not exist, url: https://i.imgur.com/G25SWK9.jpg
# Not exist, url: https://i.imgur.com/IYTrf3C.jpeg
# Not exist, url: https://i.imgur.com/VY0dvDP.jpeg
# Not exist, url: https://i.imgur.com/tUNDKoR.jpeg
# Not exist, url: https://i.imgur.com/TRKC0w6.jpeg
# Not exist, url: https://i.imgur.com/3BJmSpd.jpg
# Not exist, url: https://i.imgur.com/mIne7tb.jpg
# Not exist, url: https://i.imgur.com/55uOTLT.jpg
# Not exist, url: https://i.imgur.com/uoDGZQE.jpeg
# Not exist, url: https://i.imgur.com/zLqwqE9.jpg
# Not exist, url: https://i.imgur.com/zIjKskk.jpg
# Not exist, url: https://i.imgur.com/oG4lrDk.jpg
# Not exist, url: https://i.imgur.com/54qz84w.jpg
# Not exist, url: https://i.imgur.com/MfGrCQs.jpg
# Not exist, url: https://i.imgur.com/UwULfK7.jpg
# Not exist, url: https://i.imgur.com/AfKh9Z1.jpeg
# Not exist, url: https://i.imgur.com/E9PSVwt.jpeg
# Not exist, url: https://i.imgur.com/wjsIXOs.jpg
# Not exist, url: https://i.imgur.com/XkMDc2H.jpg
# Not exist, url: https://i.imgur.com/CpDxTes.jpg
# Not exist, url: https://i.imgur.com/MQnZgFk.jpg
# Not exist, url: https://i.imgur.com/DdaAMFq.jpeg
# Not exist, url: https://i.imgur.com/qLRQqMv.jpg
# Not exist, url: https://i.imgur.com/FTfzcaC.jpeg
# Not exist, url: https://i.imgur.com/kkG98oa.jpg
# Not exist, url: https://i.imgur.com/z4NnVo3.jpg
# Not exist, url: https://i.imgur.com/CjJrqQf.jpg
# Not exist, url: https://i.imgur.com/sgcWsFA.jpg
# Not exist, url: https://i.imgur.com/FwsbjaI.jpg
# Not exist, url: https://i.imgur.com/ViiIseP.jpg
# Not exist, url: https://i.imgur.com/QE71P2M.jpg
# Not exist, url: https://i.imgur.com/DS52iTr.jpg
# Not exist, url: https://i.imgur.com/IQIUO97.jpg
# Not exist, url: https://i.imgur.com/H85T00C.jpg
# Not exist, url: https://i.imgur.com/rEdNOdI.jpg
# File too small, url: https://d.img.vision/dddshay/011.jpg
# Not exist, url: https://i.imgur.com/6ZPeP2x.jpg
# Not exist, url: https://i.imgur.com/rzIzgxv.jpg
# File too small, url: https://d.img.vision/dddshay/fb194s7_en_1080.mp4_20231204_121159.866.jpg
# Not exist, url: https://i.imgur.com/mEq3T51.jpg
# Not exist, url: https://i.imgur.com/rP8hhua.jpg
# Not exist, url: https://i.imgur.com/aw1SEUr.jpeg
# Not exist, url: https://i.imgur.com/MTMer6D.jpg
# Not exist, url: https://i.imgur.com/5xkul1v.jpg
# Not exist, url: https://i.imgur.com/fOt0hs9.jpg
# Not exist, url: http://i.imgur.com/mlNYPgO.jpg
# Not exist, url: https://i.imgur.com/N4zQKsO.jpg
# Not exist, url: https://i.imgur.com/NGmqdHn.jpg
# Not exist, url: https://i.imgur.com/HmZs5fr.jpg
# Not exist, url: https://i.imgur.com/Tb5VnTm.jpg
# Not exist, url: https://i.imgur.com/YReS7Bf.jpg
# File too small, url: https://d.img.vision/dddshay/fb194s7_en_1080.mp4_20231204_121324.167.jpg
# Not exist, url: https://i.imgur.com/6weseo2.jpg
# Not exist, url: https://i.imgur.com/BkZV3nr.jpg
# Not exist, url: https://i.imgur.com/NSMjNrM.jpg
# ...
# Not exist, url: https://i.imgur.com/RegBIYV.jpg
# Not exist, url: https://i.imgur.com/upud715.jpg
# Not exist, url: https://i.imgur.com/A3bpXbH.jpg
# Not exist, url: https://i.imgur.com/CKc3SsE.jpg
# Not exist, url: https://i.imgur.com/phQZ14Q.jpg
# Not exist, url: https://i.imgur.com/NU5RrGN.jpg
# Not exist, url: https://i.imgur.com/9UR6Pib.jpg
# Not exist, url: https://i.imgur.com/o9YAptx.jpeg
# Not exist, url: https://i.imgur.com/s9Llyps.png
# File too small, url: https://pbs.twimg.com/media/FaD-9mYVsAAWvmd.jpg
# Not exist, url: https://i.imgur.com/iS2saR6.jpg
# File too small, url: https://pbs.twimg.com/media/FjgZH0AUoAABicp.jpg
# File too small, url: https://img.theqoo.net/img/sLyVf.jpg
# Not exist, url: https://imgur.com/3chDQJ7.jpg
# File too small, url: https://d.img.vision/dddshay/Playmate_12.jpg
# Not exist, url: https://i.imgur.com/KCTJnlX.png
# Not exist, url: https://i.imgur.com/GYfGYff.jpg
# Not exist, url: https://i.imgur.com/KkmCWMz.png
# File too small, url: https://pbs.twimg.com/media/FecfylvUYAA-2g7.jpg
# File too small, url: https://pbs.twimg.com/media/FrlAhkqaAAAcSsN.jpg
# Not exist, url: https://i.imgur.com/mBANxMt.jpg
# Not exist, url: https://i.imgur.com/HvotgRI.jpg
# Not exist, url: https://i.imgur.com/x6fHUUj.jpg
# Not exist, url: https://i.imgur.com/sgAlVpe.jpg
# Not exist, url: https://i.imgur.com/P30sczF.jpg
# Not exist, url: https://i.imgur.com/iPXYNG9.jpeg
# File too small, url: https://pbs.twimg.com/media/FvNXNu4acAEkfkw.jpg
# Not exist, url: https://imgur.com/WSQX9ac.jpg
# Not exist, url: https://i.imgur.com/OrMgMyl.jpg
# Not exist, url: https://i.imgur.com/Ggyr6YM.jpg
# File too small, url: https://d.img.vision/dddshay/CLO_004.jpg
# File too small, url: https://pbs.twimg.com/media/Fn97EeDaIAMZnMj.jpg
# Not exist, url: https://i.imgur.com/JHf89XC.png
# Not exist, url: https://i.imgur.com/rUZqXTP.png
# Not exist, url: https://i.imgur.com/KYqhAIw.png
# File too small, url: https://pbs.twimg.com/media/FcRFlGxWQAIm9hq.jpg
# Not exist, url: https://i.imgur.com/UVEn6mP.jpg
# Not exist, url: https://i.imgur.com/Iysjk1S.jpg
# Not exist, url: https://i.imgur.com/kRl74WT.jpg
# File too small, url: https://pbs.twimg.com/media/Fm5a-v1aMAEgPQ0.jpg
# File too small, url: https://pbs.twimg.com/media/Fvm42BPaUAMAn7Q.jpg
# Not exist, url: https://i.imgur.com/vtT4563.jpg
# File too small, url: https://pbs.twimg.com/media/FtLgzgYaQAAiAgT.jpg
# Not exist, url: https://i.imgur.com/2D8RdMc.jpg
# File too small, url: https://pbs.twimg.com/media/FiUpWflVsAElOfF.jpg
# Not exist, url: https://i.imgur.com/BhmKI5N.jpg
# File too small, url: https://pbs.twimg.com/media/FlDwBYaaUAESnB4.jpg
# File too small, url: https://pbs.twimg.com/media/FnZgMokacAMPaEK.jpg
# File too small, url: https://pbs.twimg.com/media/FoWmQFOacAMUnFa.jpg
# File too small, url: https://pbs.twimg.com/media/FtGMrxdaMAEJI39.jpg
# File too small, url: https://pbs.twimg.com/media/FQGUbLOacAAEMfb.jpg
# File too small, url: https://pbs.twimg.com/media/Fsmsc5JagAEaNpP.jpg
# Not exist, url: https://i.imgur.com/ZVCl6ap.jpg
# File too small, url: https://pbs.twimg.com/media/FmvjNrFacAAEZHu.jpg
# Not exist, url: https://i.imgur.com/h9d6ZEw.jpg
# Not exist, url: https://i.imgur.com/aXzl17W.jpg
# File too small, url: https://d.img.vision/dddshay/SND001.jpg
# File too small, url: https://d.img.vision/dddshay/121003.jpg
# File too small, url: https://pbs.twimg.com/media/Fp96H3KaIAU-Mst.jpg
# Not exist, url: https://i.imgur.com/5INkRIF.jpg
# Not exist, url: https://i.imgur.com/74Rnwx9.jpg
# File too small, url: https://pbs.twimg.com/media/FWQUP8HakAA0hTK.jpg
# File too small, url: https://d.img.vision/dddshay/TDM007.jpg
# File too small, url: https://d.img.vision/dddshay/MetArt_Procacis_Lucy-C_high_0046.jpg
# File too small, url: https://pbs.twimg.com/media/FuX2ClgaQAI6U9q.jpg
# File too small, url: https://pbs.twimg.com/media/FbDtY_OaMAgDtil.jpg
# Not exist, url: https://i.imgur.com/FXbQXUC.jpeg
# File too small, url: https://d.img.vision/dddshay/TDM006.jpg
# File too small, url: https://pbs.twimg.com/media/FioXYrGaMAArfgt.jpg
# Not exist, url: https://i.imgur.com/i1iCsuB.jpg
# Not exist, url: https://i.imgur.com/s8lc6Uk.jpg
# Not exist, url: https://i.imgur.com/lv8gWdq.jpg
# Not exist, url: https://i.imgur.com/B4rrIVA.jpg
# File too small, url: https://d.img.vision/dddshay/SRSHSW02.jpg
# Not exist, url: https://i.imgur.com/goWR9LR.jpg
# File too small, url: https://pbs.twimg.com/media/FppJEgaaQAInK_x.jpg
# Not exist, url: https://i.imgur.com/EIryyQD.jpg
# File too small, url: https://d.img.vision/dddshay/NDEM002.jpg
# Not exist, url: https://i.imgur.com/f1GrN0t.jpg
# Not exist, url: https://i.imgur.com/y75dc8J.png
# File too small, url: https://pbs.twimg.com/media/Fnr6MQUaMAIeu0z.jpg
# File too small, url: https://pbs.twimg.com/media/FpWED9qaUAAjeVo.jpg
# Not exist, url: https://i.imgur.com/jFmblst.jpg
# File too small, url: https://pbs.twimg.com/media/FjIpk2YVUAAHWG_.jpg
# File too small, url: https://pbs.twimg.com/media/FpkANeEaIAEKJeZ.jpg
# Not exist, url: https://i.imgur.com/XaoKfFU.jpg
# Not exist, url: https://i.imgur.com/zC9T4EW.jpg
# File too small, url: https://pbs.twimg.com/media/FjxjwWzUAAAVvrS.jpg
# Not exist, url: https://i.imgur.com/2MdxdRC.jpg
# File too small, url: https://pbs.twimg.com/media/Fu3wbbOakAY0qw_.jpg
# Not exist, url: https://i.imgur.com/Erlo6xk.jpg
# File too small, url: https://d.img.vision/dddshay/304569_full.jpg
# Not exist, url: https://i.imgur.com/2NvJVt1.jpg
# File too small, url: https://pbs.twimg.com/media/FnesbsBaMAEKnwx.jpg
# Not exist, url: https://i.imgur.com/QxwuVht.jpg
# Not exist, url: https://i.imgur.com/lNi5Ob1.jpg
# File too small, url: https://pbs.twimg.com/media/Fqh9At0akAAKCZP.jpg
# File too small, url: https://pbs.twimg.com/media/FyAttj3akAE59zX.jpg
# Not exist, url: https://i.imgur.com/WadhVnu.jpg
# Not exist, url: https://i.imgur.com/Op8oNFo.jpg
# File too small, url: https://img.theqoo.net/img/nlavN.jpg
# File too small, url: https://pbs.twimg.com/media/FsyLxWZaYAENNSF.jpg
# File too small, url: https://pbs.twimg.com/media/FltRlJgaAAIPa6D.jpg
# Not exist, url: https://i.imgur.com/MQYaZrv.jpg
# Not exist, url: http://i.imgur.com/Hq2jI22.jpg
# File too small, url: https://pbs.twimg.com/media/FuO8YJ9aIAEbXXG.jpg
# Not exist, url: https://i.imgur.com/V9LD5Ty.jpg
# Error: HTTPSConnectionPool(host='photo.xuite.net', port=443): Max retries exceeded with url: /aoshi0302/20638674/109.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7efcc23c9810>: Failed to establish a new connection: [Errno -2] Name or service not known')), url: https://photo.xuite.net/aoshi0302/20638674/109.jpg
# File too small, url: https://pbs.twimg.com/media/FmDHXbnacAAk_aA.jpg
# File too small, url: https://d.img.vision/dddshay/TDM001.jpg
# Not exist, url: https://i.imgur.com/pXCiX1Y.jpg
# Not exist, url: https://i.imgur.com/FXlZYie.jpg
# File too small, url: https://pbs.twimg.com/media/FlTshpcaUAAbvWS.jpg
# Not exist, url: https://i.imgur.com/xTo5GEd.jpg
# Not exist, url: https://i.imgur.com/BfTR7jK.jpg
# Not exist, url: https://i.imgur.com/deRnuZu.jpg
# File too small, url: https://pbs.twimg.com/media/Fxrxa90aQAE3YOs.jpg
# File too small, url: https://pbs.twimg.com/media/FrFZtakakAETwfu.jpg
# File too small, url: https://pbs.twimg.com/media/FpvDDGwaQAIUyAB.jpg
# File too small, url: https://pbs.twimg.com/media/FmKlvSZaMAMByQo.jpg
# File too small, url: https://pbs.twimg.com/media/FlxgXaVaMAAl57-.jpg
# Not exist, url: https://i.imgur.com/9X761lD.jpg
# File too small, url: https://pbs.twimg.com/media/EimbDONU0AELPWk.jpg
# Not exist, url: https://i.imgur.com/PWjhYUn.jpg
# File too small, url: https://d.img.vision/dddshay/PENTHOUSE_Gym_016.jpg
# File too small, url: https://pbs.twimg.com/media/FudrNIBaAAEGTYJ.jpg
# File too small, url: https://pbs.twimg.com/media/FtRMYBWagAMPkaP.jpg
# File too small, url: https://pbs.twimg.com/media/FqEBjljaEAAMYXj.jpg
# File too small, url: https://pbs.twimg.com/media/FtMfEYcaIAA0v3p.jpg
# File too small, url: https://pbs.twimg.com/media/FlTs0hLakAUYGO3.jpg
# File too small, url: https://pbs.twimg.com/media/FUt5dBxaMAAeTrg.jpg
# Not exist, url: https://i.imgur.com/GFm3lt2.jpg
# File too small, url: https://pbs.twimg.com/media/FnmLqVSaEAAriqa.jpg
# Not exist, url: https://i.imgur.com/AIbynND.jpg
# File too small, url: https://pbs.twimg.com/media/Fo2f-W0WcAUFkrO.jpg
# Not exist, url: https://i.imgur.com/PJWJxyQ.jpg
# Not exist, url: https://i.imgur.com/nBjtwrC.jpg
# File too small, url: https://pbs.twimg.com/media/Fkz53TfaUAAn2s8.jpg
# Not exist, url: https://i.imgur.com/VbY9Cb3.jpg
# Not exist, url: https://i.imgur.com/HC68yLe.jpeg
# File too small, url: https://i.ibb.co/kJQvVfs/7yr7-EUJca-Tw.jpg
# Not exist, url: https://i.imgur.com/Hp1Po0E.jpeg
# Not exist, url: https://i.imgur.com/aE4PU4B.jpg
# File too small, url: https://pbs.twimg.com/media/Fi4IR-CVsAA3FB7.jpg
# File too small, url: https://pbs.twimg.com/media/Frtz3A9akAEwu9W.jpg
# File too small, url: https://pbs.twimg.com/media/FkuYX5faEAEYDxK.jpg
# File too small, url: https://pbs.twimg.com/media/FsoEmKyaEAIKZwT.jpg
# Not exist, url: https://i.imgur.com/YAorT2e.jpg
# File too small, url: https://pbs.twimg.com/media/FXyjM-zVQAAxVnD.jpg
# File too small, url: https://pbs.twimg.com/media/FoCF1HZakAEUZbD.jpg
# Not exist, url: https://i.imgur.com/Wo2sRKH.jpg
# File too small, url: https://pbs.twimg.com/media/Fsj28LuaUAAcFAJ.jpg
# Not exist, url: https://i.imgur.com/1xjXyZM.jpg
# Error: HTTPSConnectionPool(host='6.share.photo.xuite.net', port=443): Max retries exceeded with url: /aoshi0302/1605361/20641041/1260244048_o.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7efcc213c3a0>: Failed to establish a new connection: [Errno -2] Name or service not known')), url: https://6.share.photo.xuite.net/aoshi0302/1605361/20641041/1260244048_o.jpg
# Not exist, url: https://i.imgur.com/anxKcud.jpeg
# Not exist, url: https://i.imgur.com/qtlDLRH.jpeg
# File too small, url: https://pbs.twimg.com/media/FuaMPIlaAAAms3h.jpg
# Not exist, url: https://i.imgur.com/skkV5qa.jpg
# Not exist, url: https://i.imgur.com/aaIX7U2.jpg
# File too small, url: https://pbs.twimg.com/media/FqTGv4DagAMK2Ga.jpg
# Not exist, url: https://i.imgur.com/SfPbOVZ.png
# File too small, url: https://pbs.twimg.com/media/Fn3vNqLaAAYqjFB.jpg
# Not exist, url: https://i.imgur.com/BBcZPWZ.jpg
# Not exist, url: https://i.imgur.com/i1qkza0.jpg
# File too small, url: https://pbs.twimg.com/media/Fid8tIhX0AAfvsx.jpg
# File too small, url: https://pbs.twimg.com/media/FklHN-3acAAK3jg.jpg
# File too small, url: https://pbs.twimg.com/media/FUp3BuaacAEodDV.jpg
# File too small, url: https://img.theqoo.net/img/uMFBd.jpg
# Not exist, url: https://i.imgur.com/4EDMIre.jpg
# File too small, url: https://pbs.twimg.com/media/FmQlj7YagAc-c7U.jpg
# Not exist, url: https://i.imgur.com/cnV22eP.jpg
# File too small, url: https://pbs.twimg.com/media/Fmj3ndfaAAA6O5X.jpg
# File too small, url: https://d.img.vision/dddshay/SRC001.jpg
# File too small, url: https://pbs.twimg.com/media/FfGqgSMVEAAGQZd.jpg
# Not exist, url: https://i.imgur.com/VyhVHo4.jpg
# Not exist, url: https://i.imgur.com/wf61NwR.jpg
# File too small, url: https://d.img.vision/dddshay/MetArt_Procacis_Lucy-C_high_0052.jpg
# Not exist, url: https://i.imgur.com/uxPhwMm.jpg
# Not exist, url: https://i.imgur.com/vyC1nYK.jpeg
# File too small, url: https://pbs.twimg.com/media/Fo70YE7aIAAeTke.jpg
# File too small, url: https://pbs.twimg.com/media/FvlFdtbagAQuUMn.jpg
# Not exist, url: https://i.imgur.com/yC5yRQT.jpeg
# Not exist, url: https://i.imgur.com/wnzdR6n.jpg
# Not exist, url: https://i.imgur.com/71CnOjJ.jpg
# File too small, url: https://pbs.twimg.com/media/FmL9kw5akAA0gKU.jpg
# File too small, url: https://pbs.twimg.com/media/Frjdwk1acAA5KFB.jpg
# File too small, url: https://pbs.twimg.com/media/Fl8XEIPacAAQ9SE.jpg
# File too small, url: https://pbs.twimg.com/media/FrL3NQJagAAklcB.jpg
# File too small, url: https://pbs.twimg.com/media/FvM9BtUaYAM4SeB.jpg
# File too small, url: https://d.img.vision/dddshay/LISABOYLE_White_Top_026.jpg
# File too small, url: https://pbs.twimg.com/media/Em34Gq8UUAA_crk.jpg
# File too small, url: https://pbs.twimg.com/media/Fd2kE19aMAAL8tE.jpg
# Not exist, url: https://imgur.com/DqHGshj.jpg
# File too small, url: https://pbs.twimg.com/media/Fmb8JRYakAM63We.jpg
# Not exist, url: https://i.imgur.com/LzNRX32.jpg
# File too small, url: https://pbs.twimg.com/media/FuT-SKKagAImdMY.jpg
# Not exist, url: https://i.imgur.com/OJvSCAG.jpg
# File too small, url: https://d.img.vision/dddshay/Mapre001_(8).jpg
# File too small, url: https://pbs.twimg.com/media/FhB10hIakAABNts.jpg
# Not exist, url: https://i.imgur.com/DohTSbE.jpg
# Not exist, url: https://i.imgur.com/aBev9ZL.jpg
# File too small, url: https://pbs.twimg.com/media/Ff_k1dQVsAAhiug.jpg
# File too small, url: https://pbs.twimg.com/media/FrvDgQ8aIAIAcE4.jpg
# File too small, url: https://pbs.twimg.com/media/E0tABj5VEAETwVE.jpg
# File too small, url: https://d.img.vision/dddshay/LISABOYLE_White_Top_018.jpg
# File too small, url: https://pbs.twimg.com/media/FrqijxjaMAIplRC.jpg
# File too small, url: https://pbs.twimg.com/media/FSjt-5KVcAEoYOg.jpg
# Not exist, url: https://i.imgur.com/EO4QPpS.jpg
# File too small, url: https://pbs.twimg.com/media/FUt5dfZaUAAmHWt.jpg
# Not exist, url: https://i.imgur.com/E8fEn9l.png
# Not exist, url: https://i.imgur.com/Mgzj824.jpg
# Not exist, url: https://i.imgur.com/3wYCwoW.jpg
# Not exist, url: https://i.imgur.com/8dUz2dH.png
# Not exist, url: https://i.imgur.com/v1xF3GI.jpg
# File too small, url: https://pbs.twimg.com/media/FdWsBVZUoAg3pdk.jpg
# File too small, url: https://pbs.twimg.com/media/FfgTX4-VUAAh2JP.jpg
# Not exist, url: https://i.imgur.com/1H9Cihi.jpg
# File too small, url: https://pbs.twimg.com/media/FvCk6wPaEAAY8j2.jpg
# Not exist, url: https://i.imgur.com/26P9Io1.jpg
# Not exist, url: https://i.imgur.com/Fi5ybo2.jpg
# Not exist, url: https://i.imgur.com/uI58nXN.jpg
# File too small, url: https://pbs.twimg.com/media/FkgFsKrUoAEd_Kb.jpg
# Not exist, url: https://i.imgur.com/PUgk9bs.jpg
# File too small, url: https://pbs.twimg.com/media/FnuaxBDaQAI_jJ3.jpg
# Not exist, url: https://i.imgur.com/gGw0f8A.jpg
# File too small, url: https://pbs.twimg.com/media/Fssg0F-aQAA68NI.jpg
# Error: HTTPSConnectionPool(host='photo.xuite.net', port=443): Max retries exceeded with url: /aoshi0302/20638674/668.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7efcc1f2c7c0>: Failed to establish a new connection: [Errno -2] Name or service not known')), url: https://photo.xuite.net/aoshi0302/20638674/668.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
#       4     os.makedirs('./not_popular_1')
#       6 download_images(result['popular']['image_urls'], './popular_1')
# ----> 7 download_images(result['not_popular']['image_urls'], './not_popular_1')
#
# Cell In[8], line 56, in download_images(urls, path)
#      51     sleep(10)
#      54 max_workers = os.cpu_count() or 1
# ---> 56 with ThreadPoolExecutor(max_workers=max_workers) as executor:
#      57     executor.map(download, urls)
#      59 # wait for all the download to finish
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
# check if every image is valid
import os
from PIL import Image

def is_valid_image(img_path):
    try:
        img = Image.open(img_path)
        img.verify()
        return True
    except Exception as e:
        print(f'Error: {e}, img_path: {img_path}')
        return False
    
img_dirs = ['./popular_1', './not_popular_1']

for img_dir in img_dirs:
    for file in os.listdir(img_dir):
        path = f'{img_dir}/{file}'
        # if it's a directory, skip it
        if os.path.isdir(path):
            continue
        if not is_valid_image(path):
            os.remove(path)
            print(f'{path} is removed')
# Out:
# Error: cannot identify image file './popular_1/NPSZZ6kr.jpg', img_path: ./popular_1/NPSZZ6kr.jpg
# ./popular_1/NPSZZ6kr.jpg is removed
# Error: cannot identify image file './popular_1/uJKZ8UG.jpg', img_path: ./popular_1/uJKZ8UG.jpg
# ./popular_1/uJKZ8UG.jpg is removed
# Error: cannot identify image file './not_popular_1/013.jpg', img_path: ./not_popular_1/013.jpg
# ./not_popular_1/013.jpg is removed
# Error: cannot identify image file './not_popular_1/cBQIIKW.jpg', img_path: ./not_popular_1/cBQIIKW.jpg
# ./not_popular_1/cBQIIKW.jpg is removed
# Error: cannot identify image file './not_popular_1/7wxcMIA.jpg', img_path: ./not_popular_1/7wxcMIA.jpg
# ./not_popular_1/7wxcMIA.jpg is removed
# Error: cannot identify image file './not_popular_1/urlelBY.jpg', img_path: ./not_popular_1/urlelBY.jpg
# ./not_popular_1/urlelBY.jpg is removed
# Error: cannot identify image file './not_popular_1/003.jpg', img_path: ./not_popular_1/003.jpg
# ./not_popular_1/003.jpg is removed
# Error: cannot identify image file './not_popular_1/8.jpg', img_path: ./not_popular_1/8.jpg
# ./not_popular_1/8.jpg is removed
# Error: cannot identify image file './not_popular_1/8E0nvgP.jpg', img_path: ./not_popular_1/8E0nvgP.jpg
# ./not_popular_1/8E0nvgP.jpg is removed
# Error: cannot identify image file './not_popular_1/FFfAzRg.jpg', img_path: ./not_popular_1/FFfAzRg.jpg
# ./not_popular_1/FFfAzRg.jpg is removed
# Error: cannot identify image file './not_popular_1/qDqDHHu.jpg', img_path: ./not_popular_1/qDqDHHu.jpg
# ./not_popular_1/qDqDHHu.jpg is removed

# %%
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
import numpy as np
import os

class CustomDataset(Dataset):
    def __init__(self, popular_dirs, not_popular_dirs):
        popular_pic_path = [f'{dir}/{path}' for dir in popular_dirs for path in os.listdir(dir) if not os.path.isdir(f'{dir}/{path}')]
        not_popular_pic_path = [f'{dir}/{path}' for dir in not_popular_dirs for path in os.listdir(dir) if not os.path.isdir(f'{dir}/{path}')]
        self.pic_dirs = popular_pic_path + not_popular_pic_path
        self.labels = [1] * len(popular_pic_path) + [0] * len(not_popular_pic_path)
        
        self.trans = transforms.Compose([transforms.ToTensor(),
                            transforms.Resize((224, 224)),
                            transforms.Normalize(mean = (0.485, 0.456, 0.406), 
                                                 std = (0.229, 0.224, 0.225))
                            ])
        
    def __len__(self):
        return len(self.pic_dirs)
    
    def __getitem__(self, idx):       
        img = Image.open(self.pic_dirs[idx])
        img = img.convert('RGB')
        img = self.trans(img)
        
        label = self.labels[idx]
        return img, label

# %%
import h5py
from tqdm import trange
def create_hdf5_dataset(dataset, output_file):
    with h5py.File(output_file, 'w') as f:
        images_dataset = f.create_dataset('images', shape=(len(dataset), 3, 224, 224), dtype='float32')
        labels_dataset = f.create_dataset('labels', shape=(len(dataset),), dtype='int32')
        
        for i in trange(len(dataset)):
            try:
                image, label = dataset[i]
                images_dataset[i] = image.numpy()
                labels_dataset[i] = label
            except Exception as e:
                print(f'Error: {e}, idx: {i}')
                print(f'img_path: {dataset.pic_dirs[i]}')
                continue

# %%
dataset = CustomDataset(['./popular_1'], ['./not_popular_1'])

create_hdf5_dataset(dataset, 'custom_dataset.hdf5')
# Out:
#  21%|██        | 12295/58770 [12:58<34:17, 22.59it/s]
# Error: broken data stream when reading image file, idx: 12291
# img_path: ./popular_1/2068.jpg
#  32%|███▏      | 18678/58770 [19:33<27:15, 24.51it/s]
# Error: image file is truncated (4 bytes not processed), idx: 18678
# img_path: ./not_popular_1/image014.jpg
# 100%|██████████| 58770/58770 [1:01:41<00:00, 15.88it/s]

# %%
import torch
class HDF5Dataset(Dataset):
    def __init__(self, file_path):
        self.file = h5py.File(file_path, 'r')
        self.images = self.file['images']
        self.labels = self.file['labels']
        self.length = len(self.images)
        
    def __len__(self):
        return self.length
    
    def __getitem__(self, idx):
        image = torch.tensor(self.images[idx])  # 加載並轉換為PyTorch tensor
        # 0, 1 to [1, 0], [0, 1]
        label = np.eye(2)[self.labels[idx]]
        label = torch.tensor(label, dtype=torch.float32)  # 加載並轉換為PyTorch tensor
        return image, label

# 使用DataLoader迭代資料集
hdf5_dataset = HDF5Dataset('./custom_dataset.hdf5')
